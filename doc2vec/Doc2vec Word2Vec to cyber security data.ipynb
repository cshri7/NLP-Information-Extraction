# %% [markdown]
# ## - Combine all data

# %%
import pandas as pd
from os import listdir

path = '../data/'
files = listdir('../data/')
df = pd.DataFrame(columns=["url", "query", "text"])

for f in files:
    temp = pd.read_csv(path + f)
    if 'article-name' in temp.columns:
        temp.rename(columns={'article-name':'name','article-url':'url','content':'text','keyword':'query'}, inplace=True)
    if len(temp) < 1:
        continue
    df = df.append(temp)
df.drop(['Unnamed: 0', 'name'], inplace=True, axis=1)

# %%
df
# Out:
#     query                                               text  \
# 0   APT30  Today FireEye released a report on a threat gr...
# 1   APT30  APT30: The Mechanics\n  Behind a Decade Long C...
# 0   APT29   \nThe sophisticated threat actor COZY BEAR wa...
# 0   APT38  Today, we are releasing details on the threat ...
# 0   APT12  +2\n2\n0\n\n2 Votes\n\n\n\n\nSymantec Official...
# 0   APT15  APT Attackers Target Japanese Word Processor Z...
# 1   APT15  China-Linked Spies Used New Malware in U.K. Go...
# 2   APT15  China-Linked Spies Used New Malware in U.K. Go...
# 0   APT34  Less than a week after Microsoft issued a patc...
# 0   APT35  Iranian Hackers Impersonate Israeli Security F...
# 1   APT35  Iran-Linked Influence Campaign Targets US, Oth...
# 2   APT35  Breaches Increasingly Discovered Internally: M...
# 0   APT32  Cyber espionage actors, now designated by Fire...
# 0   APT30  The MsnMM Campaigns [pdf]  For over half a dec...
# 1   APT30  Our recent report, “ The Chronicles of the Hel...
# 0   APT17  APT17: Hiding in Plain\n  Sight - FireEye and ...
# 0    APT3  +4\n4\n0\n\n4 Votes\n\n\n\n\nSymantec Official...
# 0   APT27  Chinese Cyberspies Target European Drone Maker...
# 1   APT27  Chinese Cyberspies Target National Data Center...
# 2   APT27  China-linked Hackers Use Signed Network Filter...
# 0   APT33  Iranian Hackers Target Aerospace, Energy Compa...
# 1   APT33  Five Threat Groups Target Industrial Systems: ...
# 2   APT33  Iranian Hackers Impersonate Israeli Security F...
# 3   APT33  Industry Reactions to Iran Cyber Retaliation O...
# 0    APT3  For the roughly three decades that the commerc...
# 1    APT3  Introduction\nIn April 2017, a previously unkn...
# 0   APT30  FireEye Uncovers Decade-Long Cyber Espionage C...
# 1   APT30  Naikon Threat Group Linked to Chinese Army\r\n...
# 2   APT30  FireEye Uncovers Decade-Long Cyber Espionage C...
# 0   APT28  The nation-state adversary group known as FANC...
# ..    ...                                                ...
# 5   APT29  Democracy at Risk from Poor Cybersecurity, For...
# 6   APT29  Cyberspies Launch U.S. Attacks Hours After Tru...
# 7   APT29  Early Toolsets Used by "Dukes" Attackers Sugge...
# 8   APT29  U.S. Officially Accuses Russia of Election Hac...
# 9   APT29  North Korea's DDoS Attacks Analyzed Based on I...
# 10  APT29  "Man-in-the-Cloud" Attacks Leverage Storage Se...
# 0   APT28  Introduction  On October 4, 2018, the MIVD hel...
# 1   APT28  Targeted attacks and malware campaigns  Operat...
# 2   APT28  On May 23 2018, our colleagues from Cisco Talo...
# 3   APT28  Targeted attacks and malware campaigns  Skygof...
# 4   APT28  Sofacy, also known as APT28, Fancy Bear, and T...
# 5   APT28  Sofacy, also known as APT28, Fancy Bear, and T...
# 6   APT28  How serious, really, is the danger presented b...
# 7   APT28  Sofacy (also known as “Fancy Bear”, “Sednit”, ...
# 8   APT28  CozyDuke (aka CozyBear, CozyCar or “Office Mon...
# 0    APT1  It's hard to believe that we've reached the en...
# 1    APT1  In the week since we released our report on AP...
# 2    APT1  On 18 February 2013, Mandiant released a repor...
# 3    APT1  A little over a year ago, Mandiant released a ...
# 4    APT1  It was only a matter of time. Today, Mandiant ...
# 5    APT1  Today, The Mandiant® Intelligence Center™ rele...
# 6    APT1  As we noted yesterday , Brandon Dixon's 9B+ bl...
# 7    APT1  The following are MD5 and SHA1 hashes for the ...
# 8    APT1  Yesterday, the U.S. Department of Justice (DOJ...
# 9    APT1  FireEye, Inc. (NASDAQ: FEYE), the leader in st...
# 0   APT10  APT10 Background  APT10 (MenuPass Group) is a ...
# 1   APT10  Introduction  In July 2018, FireEye devices de...
# 0   APT37  On Feb. 2, 2018, we published a blog detailing...
# 0   APT34  Iranian Cyberspies Exploit Recently Patched Of...
# 1   APT34  Iranian Hackers Use QUADAGENT Backdoor in Rece...
#
#                                                   url
# 0   https://www.fireeye.com//blog/executive-perspe...
# 1   https://www.fireeye.com//current-threats/apt-g...
# 0   https://www.crowdstrike.com/blog/who-is-cozy-b...
# 0   https://www.fireeye.com//blog/threat-research/...
# 0   https://www.symantec.com/connect/blogs/yet-ano...
# 0   https://www.securityweek.com/apt-attackers-tar...
# 1   https://www.securityweek.com/china-linked-spie...
# 2   https://www.securityweek.com/china-linked-spie...
# 0   https://www.fireeye.com//blog/threat-research/...
# 0   https://www.securityweek.com/iranian-hackers-i...
# 1   https://www.securityweek.com/iran-linked-influ...
# 2   https://www.securityweek.com/breaches-increasi...
# 0   https://www.fireeye.com//blog/threat-research/...
# 0   https://securelist.com/the-naikon-apt-and-the-...
# 1        https://securelist.com/the-naikon-apt/69953/
# 0   https://www.fireeye.com//current-threats/apt-g...
# 0   https://www.symantec.com/connect/blogs/buckeye...
# 0   https://www.securityweek.com/chinese-cyberspie...
# 1   https://www.securityweek.com/chinese-cyberspie...
# 2   https://www.securityweek.com/china-linked-hack...
# 0   https://www.securityweek.com/iranian-hackers-t...
# 1   https://www.securityweek.com/five-threat-group...
# 2   https://www.securityweek.com/iranian-hackers-i...
# 3   https://www.securityweek.com/industry-reaction...
# 0   https://www.crowdstrike.com/blog/crowdstrike-f...
# 1   https://www.crowdstrike.com/blog/two-birds-one...
# 0   https://www.securityweek.com/fireeye-uncovers-...
# 1   https://www.securityweek.com/naikon-threat-gro...
# 2   https://www.securityweek.com/fireeye-uncovers-...
# 0   https://www.crowdstrike.com/blog/who-is-fancy-...
# ..                                                ...
# 5   https://www.securityweek.com/democracy-risk-po...
# 6   https://www.securityweek.com/cyberspies-launch...
# 7   https://www.securityweek.com/early-toolsets-us...
# 8   https://www.securityweek.com/us-officially-acc...
# 9   https://www.securityweek.com/north-koreas-ddos...
# 10  https://www.securityweek.com/man-cloud-attacks...
# 0   https://securelist.com/threats-in-the-netherla...
# 1   https://securelist.com/it-threat-evolution-q2-...
# 2   https://securelist.com/vpnfilter-exif-to-c2-me...
# 3   https://securelist.com/it-threat-evolution-q1-...
# 4   https://securelist.com/masha-and-these-bears/8...
# 5   https://securelist.com/a-slice-of-2017-sofacy-...
# 6   https://securelist.com/exploits-how-great-is-t...
# 7   https://securelist.com/sofacy-apt-hits-high-pr...
# 8      https://securelist.com/the-cozyduke-apt/69731/
# 0   https://www.fireeye.com//blog/threat-research/...
# 1   https://www.fireeye.com//blog/threat-research/...
# 2   https://www.fireeye.com//blog/threat-research/...
# 3   https://www.fireeye.com//blog/executive-perspe...
# 4   https://www.fireeye.com//blog/threat-research/...
# 5   https://www.fireeye.com//blog/threat-research/...
# 6   https://www.fireeye.com//blog/threat-research/...
# 7   https://www.fireeye.com//blog/threat-research/...
# 8   https://www.fireeye.com//blog/threat-research/...
# 9   https://www.fireeye.com//company/press-release...
# 0   https://www.fireeye.com//blog/threat-research/...
# 1   https://www.fireeye.com//blog/threat-research/...
# 0   https://www.fireeye.com//blog/threat-research/...
# 0   https://www.securityweek.com/iranian-cyberspie...
# 1   https://www.securityweek.com/iranian-hackers-u...
#
# [232 rows x 3 columns]

# %% [markdown]
# ## - data preprocessing
#     1. stop word removal
#     2. lower case letters
#     3. non ascii character removal

# %%
from nltk.corpus import stopwords
import re
stop = stopwords.words('english')

def normalize_text(text):
    norm_text = text.lower()
    # Replace breaks with spaces
    norm_text = norm_text.replace('<br />', ' ')
    # Pad punctuation with spaces on both sides
    norm_text = re.sub(r"([\.\",\(\)!\?;:])", " \\1 ", norm_text)
    return norm_text

def remove_stop_words(text):
    return " ".join([item.lower() for item in text.split() if item not in stop])

def remove_non_ascii(text):
    return ''.join(["" if ord(i) < 32 or ord(i) > 126 else i for i in text])

df['text'] = df['text'].apply(remove_non_ascii)
df['text'] = df['text'].apply(normalize_text)
df['text'] = df['text'].apply(remove_stop_words)
df["text"] = df['text'].str.replace('[^\w\s]','')

# %% [markdown]
# ## - a simple word2vec model
#     In this section we apply simple word to vec model to tokenized data.

# %%
from gensim.models import Word2Vec
from nltk import word_tokenize

# %%
df['tokenized_text'] = df.apply(lambda row: word_tokenize(row['text']), axis=1)

# %%
model = Word2Vec(df['tokenized_text'], size=100)

# %%
for num in [1, 3, 5, 10, 12, 16, 17, 18, 19, 28, 29, 30, 32, 33, 34, 37, 38]:
    term = "apt%s"%str(num)
    if term in model.wv.vocab:
        print("Most similar words for %s"%term)
        for t in model.most_similar(term): print(t)
        print('\n')
# Out:
# Most similar words for apt1
# ('china', 0.9991138577461243)
# ('mandiant', 0.9987292289733887)
# ('lab', 0.9985379576683044)
# ('kaspersky', 0.9985246658325195)
# ('labs', 0.9983357191085815)
# ('military', 0.9983073472976685)
# ('defense', 0.9981494545936584)
# ('2017', 0.9981141686439514)
# ('according', 0.9980982542037964)
# ('iranian', 0.9977273941040039)
#
#
# Most similar words for apt3
# ('tracked', 0.9979130029678345)
# ('cozy', 0.9970728158950806)
# ('team', 0.9964618682861328)
# ('dragonfly', 0.9960741400718689)
# ('strontium', 0.9953812956809998)
# ('operation', 0.9952284097671509)
# ('behind', 0.9945781826972961)
# ('hackers', 0.9930994510650635)
# ('campaign', 0.99244624376297)
# ('cyberespionage', 0.9922792911529541)
#
#
# Most similar words for apt10
# ('sophisticated', 0.9997135400772095)
# ('entities', 0.9992278218269348)
# ('operating', 0.9990057945251465)
# ('kitten', 0.9989932179450989)
# ('region', 0.9989686608314514)
# ('naikon', 0.9988833665847778)
# ('launched', 0.9988541603088379)
# ('analyzed', 0.9988355040550232)
# ('apt32', 0.9988123178482056)
# ('revealed', 0.9987003207206726)
#
#
# Most similar words for apt17
# ('vietnamese', 0.9986779689788818)
# ('aware', 0.9984214901924133)
# ('continues', 0.9983824491500854)
# ('hellsing', 0.9982231259346008)
# ('nationstate', 0.9981635808944702)
# ('apt38', 0.9981043934822083)
# ('aligns', 0.9980053901672363)
# ('stone', 0.9979338645935059)
# ('focused', 0.9978951215744019)
# ('netherlands', 0.9978913068771362)
#
#
# Most similar words for apt28
# ('known', 0.9992156028747559)
# ('bear', 0.9970523118972778)
# ('apt', 0.9964451789855957)
# ('sofacy', 0.9962831735610962)
# ('storm', 0.9947123527526855)
# ('fancy', 0.9939792156219482)
# ('actor', 0.993463397026062)
# ('tsar', 0.9934523105621338)
# ('pawn', 0.9927756786346436)
# ('ups', 0.9882858991622925)
#
#
# Most similar words for apt29
# ('aimed', 0.9986977577209473)
# ('observed', 0.9980016946792603)
# ('including', 0.9978693723678589)
# ('attributed', 0.997548520565033)
# ('highprofile', 0.9973253607749939)
# ('recently', 0.997273325920105)
# ('2010', 0.9971299171447754)
# ('dubbed', 0.9970693588256836)
# ('buckeye', 0.9968712329864502)
# ('spotted', 0.9966543912887573)
#
#
# Most similar words for apt30
# ('prolific', 0.9989222288131714)
# ('companies', 0.9987088441848755)
# ('connected', 0.99861741065979)
# ('focuses', 0.9985596537590027)
# ('began', 0.9983980655670166)
# ('hellsing', 0.9982388019561768)
# ('governments', 0.998227059841156)
# ('variety', 0.9980995655059814)
# ('interests', 0.9980818033218384)
# ('researcher', 0.9980806708335876)
#
#
# Most similar words for apt32
# ('actively', 0.999579668045044)
# ('region', 0.9994964599609375)
# ('started', 0.9993093609809875)
# ('hacker', 0.9992772340774536)
# ('turla', 0.9992623925209045)
# ('continues', 0.9991731643676758)
# ('involved', 0.9990946054458618)
# ('kitten', 0.9990788102149963)
# ('individuals', 0.9990774989128113)
# ('however', 0.9990615844726562)
#
#
# Most similar words for apt33
# ('multiple', 0.9992877840995789)
# ('responsible', 0.9992503523826599)
# ('started', 0.9992244839668274)
# ('japanese', 0.9991694688796997)
# ('south', 0.9991474151611328)
# ('involved', 0.9990248084068298)
# ('determined', 0.9989451169967651)
# ('evidence', 0.9988258481025696)
# ('revealed', 0.9987695813179016)
# ('apt32', 0.9986560344696045)
#
#
# Most similar words for apt34
# ('shared', 0.9994332790374756)
# ('continue', 0.9993962645530701)
# ('indicate', 0.9993694424629211)
# ('added', 0.9992542266845703)
# ('particularly', 0.99919193983078)
# ('shift', 0.9991797804832458)
# ('provided', 0.999143123626709)
# ('development', 0.99912428855896)
# ('problem', 0.9990934133529663)
# ('trying', 0.9990813136100769)
#
#
# Most similar words for apt37
# ('japan', 0.9990692734718323)
# ('naikon', 0.9990512132644653)
# ('aka', 0.9989345073699951)
# ('entities', 0.9988728761672974)
# ('overlap', 0.998847246170044)
# ('highly', 0.9988194704055786)
# ('identified', 0.9988106489181519)
# ('recently', 0.9987134337425232)
# ('2007', 0.9985405802726746)
# ('noticed', 0.9984053373336792)
#
#
# Most similar words for apt38
# ('continues', 0.9994044303894043)
# ('vietnamese', 0.9993911981582642)
# ('individuals', 0.9993600845336914)
# ('countries', 0.999321699142456)
# ('stone', 0.9990360140800476)
# ('turla', 0.9990023374557495)
# ('region', 0.9989920258522034)
# ('early', 0.998987078666687)
# ('operating', 0.998982846736908)
# ('variety', 0.998943030834198)
# /home/born-2-code/.local/lib/python2.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """

# %% [markdown]
# ### here we got one interesting result for apt17 as apt28
#     but for all other word2vec results we observe that we are getting names like malware, attackers, groups, backdoor in the most similar items.
#     It might be the case that the names of attacker groups are ommited because they are phrases instead simple words.

# %% [markdown]
# ## - word2vec with bigram phrases
#     here we try to find bigram phrases from the dataset and apply word2vec model to it

# %%
from gensim.models import Phrases
from collections import Counter

# %%
bigram = Phrases()

# %%
bigram.add_vocab(df['tokenized_text'])

# %%
bigram_counter = Counter()
for key in bigram.vocab.keys():
    if len(key.split("_")) > 1:
        bigram_counter[key] += bigram.vocab[key]

for key, counts in bigram_counter.most_common(20):
    print '{0: <20} {1}'.format(key.encode("utf-8"), counts)
# Out:
# cyber_security       353
# security_conference  334
# ics_cyber            334
# document_getelementsbytagname 163
# comjsplusone_js      163
# conference_singapore 163
# google_comjsplusone  163
# script_0             163
# ciso_forum           163
# forum_half           163
# document_createelement 163
# po_src               163
# apis_google          163
# textjavascript_po    163
# type_textjavascript  163
# po_async             163
# var_po               163
# parentnode_insertbefore 163
# async_true           163
# po_type              163

# %%
bigram_model = Word2Vec(bigram[df['tokenized_text']], size=100)

# %%
for num in [1, 3, 5, 10, 12, 16, 17, 18, 19, 28, 29, 30, 32, 33, 34, 37, 38]:
    term = "apt%s"%str(num)
    if term in bigram_model.wv.vocab:
        print("Most similar words for %s"%term)
        for t in bigram_model.most_similar(term, topn=20): print(t)
        print('\n')
# Out:
# Most similar words for apt1
# (u'systems', 0.9999414086341858)
# (u'likely', 0.9999133944511414)
# (u'could', 0.9999118447303772)
# (u'actors', 0.9999102354049683)
# (u'two', 0.9999037384986877)
# (u'would', 0.9999027252197266)
# (u'data', 0.9999006986618042)
# (u'threat_actors', 0.9998990297317505)
# (u'vulnerabilities', 0.9998963475227356)
# (u'based', 0.9998944401741028)
# (u'2017', 0.9998939037322998)
# (u'different', 0.9998932480812073)
# (u'compromised', 0.9998882412910461)
# (u'recently', 0.9998868703842163)
# (u'often', 0.9998851418495178)
# (u'additional', 0.999885082244873)
# (u'says', 0.9998839497566223)
# (u'seen', 0.9998784065246582)
# (u'past', 0.9998762607574463)
# (u'symantec', 0.9998751282691956)
#
#
# Most similar words for apt3
# (u'actor', 0.9998279809951782)
# (u'multiple', 0.9998132586479187)
# (u'believe', 0.9997843503952026)
# (u'experts', 0.9997732639312744)
# (u'also_known', 0.9997693300247192)
# (u'2017', 0.9997662305831909)
# (u'north_korean', 0.999755322933197)
# (u'last_year', 0.9997542500495911)
# (u'likely', 0.9997535943984985)
# (u'based', 0.9997380375862122)
# (u'exploits', 0.9997348189353943)
# (u'analyzed', 0.9997246265411377)
# (u'advanced', 0.9997227191925049)
# (u'variety', 0.9997122883796692)
# (u'actors', 0.999709963798523)
# (u'past', 0.999708890914917)
# (u'advanced_persistent', 0.999691903591156)
# (u'domains', 0.9996856451034546)
# (u'trend_micro', 0.9996840953826904)
# (u'fancy_bear', 0.9996812343597412)
#
#
# Most similar words for apt10
# (u'detected', 0.9998729825019836)
# (u'companies', 0.9998655319213867)
# (u'tool', 0.9998607635498047)
# (u'based', 0.9998599290847778)
# (u'would', 0.9998549818992615)
# (u'2016', 0.9998499155044556)
# (u'uses', 0.9998477101325989)
# (u'recently', 0.9998471736907959)
# (u'compromised', 0.9998469352722168)
# (u'trend_micro', 0.9998456239700317)
# (u'threat_group', 0.9998452067375183)
# (u'2017', 0.9998447895050049)
# (u'many', 0.9998427629470825)
# (u'published', 0.9998427629470825)
# (u'last_year', 0.9998425245285034)
# (u'threat_actors', 0.9998418688774109)
# (u'often', 0.9998382925987244)
# (u'systems', 0.9998379945755005)
# (u'mandiant', 0.9998371601104736)
# (u'since', 0.9998371601104736)
#
#
# Most similar words for apt17
# (u'2014', 0.9995986819267273)
# (u'version', 0.9995740652084351)
# (u'point', 0.9995692372322083)
# (u'clear', 0.99956214427948)
# (u'possible', 0.9995565414428711)
# (u'stolen', 0.9995540976524353)
# (u'led', 0.9995509386062622)
# (u'services', 0.9995482563972473)
# (u'august', 0.999542236328125)
# (u'2018', 0.9995407462120056)
# (u'russian_hackers', 0.9995399713516235)
# (u'cyberattacks', 0.9995391368865967)
# (u'across', 0.9995381832122803)
# (u'cybercriminals', 0.9995379447937012)
# (u'2013', 0.9995332360267639)
# (u'main', 0.9995327591896057)
# (u'reports', 0.9995325207710266)
# (u'deployed', 0.9995283484458923)
# (u'active', 0.9995247721672058)
# (u'commands', 0.9995232820510864)
#
#
# Most similar words for apt28
# (u'researchers', 0.9996720552444458)
# (u'fireeye', 0.9996644258499146)
# (u'exploit', 0.9996479153633118)
# (u'use', 0.9995859265327454)
# (u'activity', 0.9995609521865845)
# (u'information', 0.9995589256286621)
# (u'apt', 0.9995497465133667)
# (u'including', 0.9995360374450684)
# (u'spotted', 0.9995243549346924)
# (u'several', 0.9995028972625732)
# (u'known', 0.999500036239624)
# (u'report', 0.999496340751648)
# (u'threat_actor', 0.9994584321975708)
# (u'targeting', 0.9994409084320068)
# (u'may', 0.99944007396698)
# (u'observed', 0.9994345307350159)
# (u'using', 0.9994158148765564)
# (u'attack', 0.9994133710861206)
# (u'one', 0.9994004964828491)
# (u'attackers', 0.9993690848350525)
#
#
# Most similar words for apt29
# (u'attribution', 0.9998936653137207)
# (u'like', 0.9998860359191895)
# (u'2015', 0.9998851418495178)
# (u'software', 0.9998846054077148)
# (u'include', 0.9998725056648254)
# (u'least', 0.9998712539672852)
# (u'revealed', 0.9998676776885986)
# (u'emails', 0.9998659491539001)
# (u'legitimate', 0.9998635053634644)
# (u'another', 0.9998623132705688)
# (u'sophisticated', 0.9998588562011719)
# (u'intelligence', 0.9998577237129211)
# (u'computer', 0.9998571872711182)
# (u'backdoors', 0.9998565912246704)
# (u'servers', 0.9998531341552734)
# (u'designed', 0.9998510479927063)
# (u'networks', 0.9998500347137451)
# (u'appears', 0.9998495578765869)
# (u'apt33', 0.9998490810394287)
# (u'tracked', 0.9998488426208496)
#
#
# Most similar words for apt30
# (u'way', 0.9995005130767822)
# (u'indicators', 0.9994634985923767)
# (u'websites', 0.9994466304779053)
# (u'evidence', 0.999442458152771)
# (u'designed', 0.999441385269165)
# (u'initial', 0.999439001083374)
# (u'russian_government', 0.9994328022003174)
# (u'details', 0.9994274973869324)
# (u'cases', 0.9994266033172607)
# (u'google', 0.9994262456893921)
# (u'apt33', 0.9994260668754578)
# (u'analysis', 0.9994186162948608)
# (u'limited', 0.9994162321090698)
# (u'tracked', 0.9994081258773804)
# (u'efforts', 0.9994062185287476)
# (u'continue', 0.9994043111801147)
# (u'october', 0.9994041323661804)
# (u'makes', 0.999403715133667)
# (u'devices', 0.9994008541107178)
# (u'media', 0.9993982315063477)
#
#
# Most similar words for apt32
# (u'techniques', 0.9999167919158936)
# (u'threat_group', 0.9998996257781982)
# (u'part', 0.9998980760574341)
# (u'set', 0.9998964071273804)
# (u'many', 0.9998956918716431)
# (u'provided', 0.999893844127655)
# (u'since', 0.9998924732208252)
# (u'appears', 0.999883770942688)
# (u'analysis', 0.9998806715011597)
# (u'emails', 0.9998794198036194)
# (u'according', 0.9998788833618164)
# (u'networks', 0.9998770952224731)
# (u'well', 0.9998760223388672)
# (u'military', 0.9998757839202881)
# (u'least', 0.9998751282691956)
# (u'2015', 0.9998748302459717)
# (u'companies', 0.9998743534088135)
# (u'described', 0.9998705983161926)
# (u'another', 0.9998704195022583)
# (u'previously', 0.9998703002929688)
#
#
# Most similar words for apt33
# (u'tracked', 0.9999077320098877)
# (u'include', 0.9998898506164551)
# (u'provided', 0.9998894929885864)
# (u'attribution', 0.9998872876167297)
# (u'continue', 0.9998824596405029)
# (u'details', 0.9998781681060791)
# (u'software', 0.9998760223388672)
# (u'designed', 0.9998737573623657)
# (u'networks', 0.999873161315918)
# (u'emails', 0.9998731017112732)
# (u'statesponsored', 0.9998718500137329)
# (u'appears', 0.9998716711997986)
# (u'analysis', 0.9998705387115479)
# (u'sophisticated', 0.9998688101768494)
# (u'evidence', 0.9998676776885986)
# (u'2015', 0.9998669624328613)
# (u'media', 0.9998632073402405)
# (u'least', 0.9998621940612793)
# (u'military', 0.9998610019683838)
# (u'apt32', 0.9998570084571838)
#
#
# Most similar words for apt34
# (u'release', 0.9997557401657104)
# (u'versions', 0.9997547268867493)
# (u'still', 0.9997528791427612)
# (u'connections', 0.9997522234916687)
# (u'example', 0.9997501969337463)
# (u'run', 0.9997470378875732)
# (u'risk', 0.9997459650039673)
# (u'accounts', 0.9997422695159912)
# (u'remote', 0.9997403621673584)
# (u'breach', 0.9997397661209106)
# (u'key', 0.9997377395629883)
# (u'fake', 0.9997360706329346)
# (u'list', 0.9997304081916809)
# (u'users', 0.9997274875640869)
# (u'take', 0.9997252821922302)
# (u'naikon', 0.9997222423553467)
# (u'get', 0.9997210502624512)
# (u'firms', 0.9997210502624512)
# (u'order', 0.9997209906578064)
# (u'email', 0.9997183084487915)
#
#
# Most similar words for apt37
# (u'nato', 0.9998037815093994)
# (u'continues', 0.9997950792312622)
# (u'work', 0.9997920989990234)
# (u'able', 0.9997884035110474)
# (u'find', 0.9997839331626892)
# (u'significant', 0.9997833967208862)
# (u'computers', 0.9997819662094116)
# (u'called', 0.9997787475585938)
# (u'possible', 0.9997774362564087)
# (u'back', 0.999775230884552)
# (u'sectors', 0.9997749924659729)
# (u'energy', 0.999774694442749)
# (u'within', 0.9997701644897461)
# (u'2013', 0.9997696280479431)
# (u'clear', 0.9997689127922058)
# (u'public', 0.9997654557228088)
# (u'july', 0.9997652769088745)
# (u'active', 0.9997649192810059)
# (u'made', 0.999764621257782)
# (u'like', 0.9997555017471313)
#
#
# Most similar words for apt38
# (u'software', 0.9998067617416382)
# (u'attribution', 0.9998055100440979)
# (u'least', 0.9997978806495667)
# (u'update', 0.9997957348823547)
# (u'emails', 0.9997947216033936)
# (u'backdoors', 0.9997928142547607)
# (u'networks', 0.999789834022522)
# (u'include', 0.9997842311859131)
# (u'2015', 0.9997820854187012)
# (u'another', 0.9997803568840027)
# (u'appears', 0.9997801780700684)
# (u'time', 0.9997801780700684)
# (u'apt29', 0.9997771978378296)
# (u'like', 0.9997736811637878)
# (u'targeted_attacks', 0.9997725486755371)
# (u'military', 0.9997715950012207)
# (u'already', 0.9997713565826416)
# (u'services', 0.9997669458389282)
# (u'apt33', 0.9997654557228088)
# (u'well', 0.9997639060020447)
# /home/born-2-code/.local/lib/python2.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """

# %% [markdown]
# ### After applying bigram phrases still we cannot see the desired results.

# %% [markdown]
# ## Doc2Vec model

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %%
df_doc = df[['query', 'text']]

# %%
df_doc = df_doc.groupby(['query'],as_index=False).first()

# %%
tagged_data = [TaggedDocument(words=word_tokenize(df_doc['text'].iloc[i]), tags=[df_doc['query'].iloc[i]]) for i in range(len(df_doc))]

# %%
max_epochs = 100
vec_size = 20
alpha = 0.025

model = Doc2Vec(size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)
  
model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    model.alpha -= 0.0002
    model.min_alpha = model.alpha

model.save("d2v.model")
print("Model Saved")
# Out:
# /home/born-2-code/.local/lib/python2.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   app.launch_new_instance()
# Model Saved

# %%
for num in [1, 3, 5, 10, 12, 16, 17, 18, 19, 28, 29, 30, 32, 33, 34, 37, 38]:
    term = "APT%s"%str(num)
    if term in list(df_doc['query']):
        print(term)
        print(model.docvecs.most_similar(term))
        print('\n')
# Out:
# APT1
# [('APT28', 0.7839778065681458), ('APT29', 0.7835925817489624), ('APT15', 0.7258604168891907), ('APT27', 0.7226715087890625), ('APT18', 0.7201363444328308), ('APT38', 0.7148082256317139), ('APT12', 0.70294189453125), ('APT17', 0.6991536617279053), ('APT3', 0.6950184106826782), ('APT35', 0.6926254034042358)]
#
#
# APT3
# [('APT17', 0.7516874670982361), ('APT37', 0.7471446394920349), ('APT29', 0.7417770028114319), ('APT38', 0.7213995456695557), ('APT28', 0.7209811210632324), ('APT12', 0.6950358748435974), ('APT1', 0.6950184106826782), ('APT16', 0.6718595027923584), ('APT35', 0.6598621606826782), ('APT34', 0.6495394706726074)]
#
#
# APT10
# [('APT35', 0.8204693794250488), ('APT29', 0.7824466228485107), ('APT17', 0.731864333152771), ('APT33', 0.7253490090370178), ('APT27', 0.7108751535415649), ('APT18', 0.7073136568069458), ('APT15', 0.686213493347168), ('APT16', 0.6819599866867065), ('APT28', 0.6761863231658936), ('APT34', 0.6420496702194214)]
#
#
# APT12
# [('APT15', 0.8837562799453735), ('APT30', 0.7572991847991943), ('APT27', 0.7277055978775024), ('APT18', 0.7253491282463074), ('APT33', 0.7156038284301758), ('APT1', 0.70294189453125), ('APT16', 0.7021207809448242), ('APT3', 0.6950358748435974), ('APT28', 0.6804450750350952), ('APT35', 0.6764209270477295)]
#
#
# APT16
# [('APT27', 0.8026472330093384), ('APT18', 0.8021819591522217), ('APT33', 0.781478762626648), ('APT15', 0.7779051065444946), ('APT17', 0.7537260055541992), ('APT35', 0.7430102229118347), ('APT37', 0.7398223876953125), ('APT29', 0.7211832404136658), ('APT28', 0.7064602375030518), ('APT12', 0.702120840549469)]
#
#
# APT17
# [('APT29', 0.8238643407821655), ('APT37', 0.8171483278274536), ('APT16', 0.7537260055541992), ('APT3', 0.7516874670982361), ('APT35', 0.7387498617172241), ('APT38', 0.7321697473526001), ('APT10', 0.731864333152771), ('APT34', 0.7310976982116699), ('APT28', 0.7217957973480225), ('APT32', 0.7037481665611267)]
#
#
# APT18
# [('APT27', 0.9998936653137207), ('APT16', 0.8021818399429321), ('APT33', 0.778609037399292), ('APT28', 0.7705044746398926), ('APT37', 0.7434091567993164), ('APT15', 0.7261635065078735), ('APT12', 0.7253490686416626), ('APT35', 0.7210760116577148), ('APT1', 0.7201363444328308), ('APT29', 0.7138354182243347)]
#
#
# APT28
# [('APT29', 0.9237245321273804), ('APT1', 0.7839778065681458), ('APT27', 0.7707185745239258), ('APT18', 0.7705044746398926), ('APT38', 0.7241305708885193), ('APT17', 0.7217957973480225), ('APT3', 0.7209811210632324), ('APT35', 0.719372034072876), ('APT34', 0.708167552947998), ('APT37', 0.7078328132629395)]
#
#
# APT29
# [('APT28', 0.9237246513366699), ('APT17', 0.8238644599914551), ('APT35', 0.7933390140533447), ('APT38', 0.7842360734939575), ('APT1', 0.7835926413536072), ('APT10', 0.7824466228485107), ('APT34', 0.7510839700698853), ('APT37', 0.7443829774856567), ('APT3', 0.7417770624160767), ('APT32', 0.732238233089447)]
#
#
# APT30
# [('APT12', 0.7572992444038391), ('APT34', 0.7569599151611328), ('APT35', 0.7485737800598145), ('APT15', 0.7263115048408508), ('APT27', 0.7161681056022644), ('APT29', 0.7157114744186401), ('APT18', 0.7117965221405029), ('APT33', 0.7068182229995728), ('APT38', 0.6988357305526733), ('APT1', 0.6782816648483276)]
#
#
# APT32
# [('APT29', 0.7322381734848022), ('APT17', 0.7037481665611267), ('APT18', 0.7003191113471985), ('APT27', 0.7002381682395935), ('APT28', 0.6910601854324341), ('APT16', 0.6872234344482422), ('APT38', 0.6699227690696716), ('APT37', 0.6695466041564941), ('APT30', 0.6640284061431885), ('APT15', 0.6497406363487244)]
#
#
# APT33
# [('APT37', 0.7931591272354126), ('APT16', 0.781478762626648), ('APT27', 0.780248761177063), ('APT18', 0.778609037399292), ('APT35', 0.7766160368919373), ('APT15', 0.7409138679504395), ('APT10', 0.7253490090370178), ('APT12', 0.7156038284301758), ('APT30', 0.7068181037902832), ('APT34', 0.7013332843780518)]
#
#
# APT34
# [('APT30', 0.7569597959518433), ('APT29', 0.7510838508605957), ('APT38', 0.7322594523429871), ('APT17', 0.7310976386070251), ('APT37', 0.7224102020263672), ('APT28', 0.708167552947998), ('APT27', 0.7024223804473877), ('APT18', 0.7016156911849976), ('APT33', 0.701333224773407), ('APT16', 0.6723531484603882)]
#
#
# APT37
# [('APT17', 0.8171483874320984), ('APT33', 0.7931591272354126), ('APT3', 0.7471445798873901), ('APT29', 0.7443828582763672), ('APT18', 0.7434091567993164), ('APT27', 0.741661548614502), ('APT16', 0.7398223876953125), ('APT34', 0.7224102020263672), ('APT38', 0.7206594944000244), ('APT35', 0.7107328176498413)]
#
#
# APT38
# [('APT29', 0.7842360138893127), ('APT34', 0.7322595119476318), ('APT17', 0.7321697473526001), ('APT28', 0.7241305112838745), ('APT3', 0.7213996052742004), ('APT37', 0.7206594944000244), ('APT1', 0.7148082256317139), ('APT30', 0.6988356113433838), ('APT18', 0.6943362951278687), ('APT27', 0.6937530040740967)]

# %%
model.similar_by_word('apt12')
# Out:
# /home/born-2-code/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# [('belonging', 0.9390033483505249),
#  ('possibly', 0.8240631818771362),
#  ('wekby', 0.7597745656967163),
#  ('hotel', 0.7557625770568848),
#  ('ga', 0.7460821270942688),
#  ('turla', 0.7373042702674866),
#  ('sword', 0.7202558517456055),
#  ('platform', 0.7161414623260498),
#  ('significant', 0.7154147028923035),
#  ('succeeded', 0.7152796983718872)]

# %% [markdown]
# ## doc2vec with each sentence as a document
